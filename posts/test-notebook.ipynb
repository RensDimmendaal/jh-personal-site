# %% [raw]
# ---
# title: Test Notebook Post
# date: 2026-03-31
# excerpt: A test post written as a Jupyter notebook.
# tags:
#   - test
# ---

# %% [markdown]
# # Test Notebook Post
#
# This is a test notebook with **markdown cells** to verify `.ipynb` rendering.

# %% [markdown]
# ## Section Two
#
# Here's another markdown cell with:
#
# - A bullet list
# - With multiple items
# - And some `inline code`
#
# And a [link](https://fast.ai) for good measure.

# %%
def greet(nm:str):
    return f"Hello {nm}"

greet("Jack")
# Out:
# 'Hello Jack'

# %% [raw]
#  ________________________________________
# / You have Egyptian flu: you're going to \
# \ be a mummy.                            /
#  ----------------------------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||
